# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavraj604/Assignment-1-py-/blob/main/Data_Cleaning_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load data

# %%
data = pd.read_csv("/content/Data-cleaning-for-beginners-using-pandas.csv")

# %% [markdown]
# - head()
# - tail()
# - info()
# - dtypes()
# - describe()
# - shape

# %%
data.head()
# Out:
#    Index   Age     Salary  Rating       Location  Established Easy Apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
data.tail()
# Out:
#     Index   Age     Salary  Rating       Location  Established Easy Apply
# 24     24  13.0  $44k-$99k    -1.0    New York,Ny         1987         -1
# 25     25  55.0  $44k-$99k     0.0  Australia Aus         1980       TRUE
# 26     26   NaN  $55k-$66k     NaN       India,In         1934       TRUE
# 27     27  52.0  $44k-$99k     5.4       India,In         1935         -1
# 28     28   NaN  $39k-$88k     3.4  Australia Aus         1932         -1

# %%
data.sample(3)
# Out:
#     Index   Age     Salary  Rating       Location  Established Easy Apply
# 7       7  44.0  $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0  $44k-$99k     5.4    New York,Ny           -1         -1
# 24     24  13.0  $44k-$99k    -1.0    New York,Ny         1987         -1

# %%
data.shape
# Out:
# (29, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          22 non-null     float64
#  2   Salary       29 non-null     object
#  3   Rating       28 non-null     float64
#  4   Location     29 non-null     object
#  5   Established  29 non-null     int64
#  6   Easy Apply   29 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.7+ KB

# %%
data.isna().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Index', 'Age', 'Salary', 'Rating', 'Location', 'Established',
#        'Easy Apply'],
#       dtype='object')

# %%
data.columns = data.columns.str.lower().str.replace(' ','_')

# %%
data.head()
# Out:
#    index   age     salary  rating       location  established easy_apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %% [markdown]
# # Age

# %%
avg_age = data.age.mean()

# %%
data['age'] = data['age'].fillna(avg_age)
data['age'] = data['age'].round(decimals=1)
data['age']
# Out:
# 0     44.0
# 1     66.0
# 2     39.0
# 3     64.0
# 4     25.0
# 5     44.0
# 6     21.0
# 7     44.0
# 8     35.0
# 9     22.0
# 10    55.0
# 11    44.0
# 12    39.0
# 13    25.0
# 14    66.0
# 15    44.0
# 16    19.0
# 17    39.0
# 18    35.0
# 19    32.0
# 20    39.0
# 21    35.0
# 22    19.0
# 23    39.0
# 24    13.0
# 25    55.0
# 26    39.0
# 27    52.0
# 28    39.0
# Name: age, dtype: float64

# %%
data['age'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Salary

# %%
data['salary'] = data['salary'].apply(lambda x:x.replace('$',''))

# %%
data['salary']
# Out:
# 0      44k-99k
# 1      55k-66k
# 2      77k-89k
# 3      44k-99k
# 4      44k-99k
# 5      77k-89k
# 6      44k-99k
# 7      44k-99k
# 8      44k-99k
# 9      44k-99k
# 10     10k-49k
# 11     10k-49k
# 12     44k-99k
# 13     44k-99k
# 14     44k-99k
# 15    88k-101k
# 16     19k-40k
# 17     44k-99k
# 18     44k-99k
# 19     44k-99k
# 20     44k-99k
# 21     44k-99k
# 22     55k-66k
# 23     44k-99k
# 24     44k-99k
# 25     44k-99k
# 26     55k-66k
# 27     44k-99k
# 28     39k-88k
# Name: salary, dtype: object

# %%
data.head()
# Out:
#    index  age   salary  rating       location  established easy_apply
# 0      0   44  44k-99k     5.4       India,In         1999       TRUE
# 1      1   66  55k-66k     3.5    New York,Ny         2002       TRUE
# 2      2   39  77k-89k    -1.0    New York,Ny           -1         -1
# 3      3   64  44k-99k     4.4       India In         1988         -1
# 4      4   25  44k-99k     6.4  Australia Aus         2002         -1

# %%
data['age'] = data['age'].astype(int)

# %% [markdown]
# # Rating

# %%
[15,10,15,5,12,90]
# Out:
# [15, 10, 15, 5, 12, 90]
